# %%
#Question 1
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

f = cv.imread("spider.png",cv.IMREAD_GRAYSCALE)
assert f is not None

gamma = [0.2, 0.8, 1.2, 2]
for i in gamma:
    t = np.array([(p/255)**i*255 for p in range(0,256)]).astype(np.uint8)
    g = cv.LUT(f,t)

    fig, ax = plt.subplots()
    ax.plot(t)

    fig, ax = plt.subplots(2,1)
    
    cv.namedWindow("Image", cv.WINDOW_AUTOSIZE)
    cv.imshow("Image",f)
    cv.waitKey(0)
    ax[0].imshow(cv.cvtColor(f,cv.COLOR_BGR2RGB))
    ax[0].axis('off')
    cv.imshow("Image",g)
    cv.waitKey(0)
    ax[1].imshow(cv.cvtColor(g,cv.COLOR_BGR2RGB))
    ax[1].axis('off')
    cv.destroyAllWindows()

# %%
#Question 2
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

f = cv.imread("spider.png",cv.IMREAD_GRAYSCALE)
assert f is not None

t1 = np.linspace(0,100,50)
t2 = np.linspace(100,255,150)
t3 = np.linspace(255,255,56)

t = np.concatenate((t1,t2,t3),axis=0).astype(np.uint8)

fig,ax= plt.subplots()
ax.plot(t)
ax.set_aspect('equal')
assert len(t)==256
g = cv.LUT(f,t)

fig, ax = plt.subplots(2,1)

cv.namedWindow("Image", cv.WINDOW_AUTOSIZE)
cv.imshow("Image",f)
cv.waitKey(0)
ax[0].imshow(cv.cvtColor(f,cv.COLOR_BGR2RGB))
ax[0].axis('off')
cv.imshow("Image",g)
cv.waitKey(0)
ax[1].imshow(cv.cvtColor(g,cv.COLOR_BGR2RGB))
ax[1].axis('off')
cv.destroyAllWindows()

# %%
#Question 3(a)
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread("shells.tif", cv.IMREAD_GRAYSCALE)
hist = cv.calcHist([img],[0],None,[256],[0,256])
plt.plot(hist)
plt.xlim([0,256])
plt.show()

# %%
#Question 3(b), (c)
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('shells.tif',cv.IMREAD_GRAYSCALE)

hist,bins = np.histogram(img.ravel(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf*hist.max()/cdf.max()
plt.plot(cdf_normalized,color='b')
plt.hist(img.flatten(),256,[0,256],color='r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'),loc='upper left')
plt.title('Histogram of the Original Image')
plt.show()
equ= cv.equalizeHist(img)
hist,bins = np.histogram(equ.ravel(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf*hist.max()/cdf.max()
plt.plot(cdf_normalized,color='b')
plt.hist(equ.flatten(),256,[0,256],color='r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'),loc='upper left')
plt.title('Histogram of the Equalized Image')
plt.show()
res = np.hstack((img,equ))
plt.axis('off')
plt.imshow(res,cmap='gray')

# %%
#Question 4 (a)
img = cv.imread('zion_pass.jpg')

fig, ax = plt.subplots(2,1)
cv.imshow('original image', img )
ax[0].imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))
ax[0].axis('off')
cv.waitKey(0)

hsv_img = cv.cvtColor(img, cv.COLOR_BGR2HSV)
h,s,v = cv.split(hsv_img)

value = 60
s_new = cv.add(s,value) 
hsv_new = cv.merge([h, s_new, v])
rgb_new = cv.cvtColor(hsv_new, cv.COLOR_HSV2RGB)


cv.imshow('saturated image',rgb_new)
ax[1].imshow(cv.cvtColor(rgb_new,cv.COLOR_BGR2RGB))
ax[1].axis('off')
cv.waitKey(0)
cv.destroyAllWindows()
plt.show()

# %%
#Question 4 (b)
img = cv.imread('zion_pass.jpg')

hsv_img = cv.cvtColor(img, cv.COLOR_BGR2HSV)
h,s,v = cv.split(hsv_img)

value = 60
h_new = cv.add(h,value) 
hsv_new = cv.merge([h_new, s, v])
rgb_new = cv.cvtColor(hsv_new, cv.COLOR_HSV2RGB)

fig, ax = plt.subplots(2,1)
cv.imshow('original image', img )
ax[0].imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))
ax[0].axis('off')
cv.waitKey(0)
cv.imshow('saturated image',rgb_new)
ax[1].imshow(cv.cvtColor(rgb_new,cv.COLOR_BGR2RGB))
ax[1].axis('off')
cv.waitKey(0)
cv.destroyAllWindows()
plt.show()
